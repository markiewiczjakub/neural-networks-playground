# %%
# https://github.com/karpathy/micrograd/blob/master/demo.ipynb

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import os, sys
sys.path.append(os.path.abspath('..'))
from micrograd.value import Value
from micrograd.mlp import Neuron, Layer, MLP

# %%
np.random.seed(1337)
random.seed(1337)

# %%
from sklearn.datasets import make_moons, make_blobs

# make_moons - two interleaving half circles, handy for classification
X, y = make_moons(n_samples=100, noise=0.1)

y = y * 2 - 1
plt.figure(figsize=(5,5))
plt.scatter(X[:,0], X[:,1], c=y, s=20, cmap='jet')

# %%
# initialize a model 
model = MLP(2, [16, 16, 1]) # 2-layer neural network
print("number of parameters", len(model.parameters()))
# Out:
# number of parameters 337

# %%
def loss(batch_size=None):
    if batch_size is None:
        Xb, yb = X, y
    else:
        batch = np.random.permutation(X.shape[0])[:batch_size]
        Xb, yb = X[batch], y[batch]

    # X = [[x0, y0], [x1, y1], ...]
    
    # Value(Xb[i][j])
    inputs = [list(map(Value, row)) for row in Xb]

    # model(inputs[i])
    scores = list(map(model, inputs))

    # hinge loss - l(y) = 1 - t * y used for training classifiers
    losses = [(1 + -yi * scorei).relu() for yi, scorei in zip(yb, scores)]
    data_loss = sum(losses) / len(losses)

    # L2 regularization
    alpha = 1e-4
    reg_loss = alpha * sum((p*p for p in model.parameters()))
    total_loss = data_loss + reg_loss

    accuracy = [(yi > 0) == (scorei.data > 0) for yi, scorei in zip(yb, scores)]
    return total_loss, sum(accuracy) / len(accuracy)

total_loss, acc = loss()
print(total_loss, acc)
# Out:
# Value(data=1.1815924818239036, grad=0) 0.5

# %%
# optimization
for k in range(100):
    
    # forward
    total_loss, acc = loss()
    
    # backward
    model.zero_grad()
    total_loss.backward()
    
    # update (sgd)
    learning_rate = 1.0 - 0.9*k/100
    for p in model.parameters():
        p.data -= learning_rate * p.grad
    
    if k % 1 == 0:
        print(f"step {k} loss {total_loss.data}, accuracy {acc*100}%")
# Out:
# step 0 loss 1.1815924818239036, accuracy 50.0%
# step 1 loss 3.122629076206581, accuracy 50.0%
# step 2 loss 0.9954343872910139, accuracy 66.0%
# step 3 loss 0.9268451125083014, accuracy 50.0%
# step 4 loss 0.4576321330876034, accuracy 78.0%
# step 5 loss 0.4117224237975214, accuracy 90.0%
# step 6 loss 0.8657108727684601, accuracy 78.0%
# step 7 loss 0.29166887811300285, accuracy 88.0%
# step 8 loss 0.26158312750662444, accuracy 89.0%
# step 9 loss 0.2619789627820203, accuracy 88.0%
# step 10 loss 0.3176038682804335, accuracy 89.0%
# step 11 loss 0.2398392097126107, accuracy 90.0%
# step 12 loss 0.3149988422161902, accuracy 89.0%
# step 13 loss 0.25036834450082257, accuracy 89.0%
# step 14 loss 0.32130143236036357, accuracy 90.0%
# step 15 loss 0.21742970390898125, accuracy 91.0%
# step 16 loss 0.24045865276693296, accuracy 90.0%
# step 17 loss 0.2030977517800738, accuracy 92.0%
# step 18 loss 0.29212050685627305, accuracy 89.0%
# step 19 loss 0.19733871257273528, accuracy 91.0%
# step 20 loss 0.22577744378801215, accuracy 92.0%
# step 21 loss 0.17756563115594395, accuracy 93.0%
# step 22 loss 0.25454477992377766, accuracy 91.0%
# step 23 loss 0.15896317854032146, accuracy 94.0%
# step 24 loss 0.1824731622439626, accuracy 94.0%
# step 25 loss 0.16090927250004852, accuracy 95.0%
# step 26 loss 0.27149692619907617, accuracy 91.0%
# step 27 loss 0.13763009388999187, accuracy 95.0%
# step 28 loss 0.16394633464590475, accuracy 94.0%
# step 29 loss 0.12939953854547745, accuracy 97.0%
# step 30 loss 0.35027887399624985, accuracy 89.0%
# step 31 loss 0.11931592923701399, accuracy 94.0%
# step 32 loss 0.1406965096978682, accuracy 96.0%
# step 33 loss 0.27946993650280716, accuracy 91.0%
# step 34 loss 0.10823579866170308, accuracy 94.0%
# step 35 loss 0.10520118790013808, accuracy 97.0%
# step 36 loss 0.16094131264080305, accuracy 95.0%
# step 37 loss 0.07296199685806731, accuracy 99.0%
# step 38 loss 0.0928510980621746, accuracy 99.0%
# step 39 loss 0.30494702924905137, accuracy 90.0%
# step 40 loss 0.09745912726682802, accuracy 95.0%
# step 41 loss 0.06750108117526518, accuracy 99.0%
# step 42 loss 0.0710255786829068, accuracy 99.0%
# step 43 loss 0.12972028082249065, accuracy 98.0%
# step 44 loss 0.47186714868316, accuracy 87.0%
# step 45 loss 0.15127258083005732, accuracy 95.0%
# step 46 loss 0.08699921747939629, accuracy 97.0%
# step 47 loss 0.06234177231929067, accuracy 99.0%
# step 48 loss 0.05433375794794742, accuracy 99.0%
# step 49 loss 0.056030469528380984, accuracy 100.0%
# step 50 loss 0.05243801242621003, accuracy 99.0%
# step 51 loss 0.10809773889097779, accuracy 97.0%
# step 52 loss 0.041233906431383874, accuracy 100.0%
# step 53 loss 0.03686426841779522, accuracy 100.0%
# step 54 loss 0.03416643143522921, accuracy 100.0%
# step 55 loss 0.033092246953309, accuracy 100.0%
# step 56 loss 0.03156095682745885, accuracy 100.0%
# step 57 loss 0.03232239560325137, accuracy 100.0%
# step 58 loss 0.045841036408966834, accuracy 100.0%
# step 59 loss 0.13464597929838346, accuracy 96.0%
# step 60 loss 0.036989018681936506, accuracy 100.0%
# step 61 loss 0.029757884388743126, accuracy 100.0%
# step 62 loss 0.04638295768058523, accuracy 99.0%
# step 63 loss 0.0507179791648559, accuracy 100.0%
# step 64 loss 0.13354335351443108, accuracy 96.0%
# step 65 loss 0.03688161008096849, accuracy 100.0%
# step 66 loss 0.024507238784181342, accuracy 100.0%
# step 67 loss 0.020233048001109935, accuracy 100.0%
# step 68 loss 0.019703815016234187, accuracy 100.0%
# step 69 loss 0.017974243693342072, accuracy 100.0%
# step 70 loss 0.018699428103430643, accuracy 100.0%
# step 71 loss 0.017231595626386022, accuracy 100.0%
# step 72 loss 0.016839848840917892, accuracy 100.0%
# step 73 loss 0.017399753855698502, accuracy 100.0%
# step 74 loss 0.017402223449460685, accuracy 100.0%
# step 75 loss 0.017913683570883104, accuracy 100.0%
# step 76 loss 0.016433716915486868, accuracy 100.0%
# step 77 loss 0.01691409489273956, accuracy 100.0%
# step 78 loss 0.016469210820895936, accuracy 100.0%
# step 79 loss 0.01595951563778185, accuracy 100.0%
# step 80 loss 0.016688519606967232, accuracy 100.0%
# step 81 loss 0.015955067270206208, accuracy 100.0%
# step 82 loss 0.0158284096962702, accuracy 100.0%
# step 83 loss 0.015089939299159957, accuracy 100.0%
# step 84 loss 0.015917959114951613, accuracy 100.0%
# step 85 loss 0.014635911286296871, accuracy 100.0%
# step 86 loss 0.014499574479485912, accuracy 100.0%
# step 87 loss 0.014218277585936018, accuracy 100.0%
# step 88 loss 0.013991243909194677, accuracy 100.0%
# step 89 loss 0.014097817259746494, accuracy 100.0%
# step 90 loss 0.014652049002652025, accuracy 100.0%
# step 91 loss 0.0142345518005516, accuracy 100.0%
# step 92 loss 0.014445468469756596, accuracy 100.0%
# step 93 loss 0.013986374614227632, accuracy 100.0%
# step 94 loss 0.014246718078794617, accuracy 100.0%
# step 95 loss 0.013747741047263892, accuracy 100.0%
# step 96 loss 0.014055746656420752, accuracy 100.0%
# step 97 loss 0.013519387859320275, accuracy 100.0%
# step 98 loss 0.01362432135134255, accuracy 100.0%
# step 99 loss 0.013524357999931864, accuracy 100.0%

# %%
# visualize decision boundary

h = 0.25
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
x_ = np.arange(x_min, x_max, h) # <x_min, x_max) with step h
y_ = np.arange(y_min, y_max, h) # <y_min, y_max) with step h
xx, yy = np.meshgrid(x_, y_) # 2D grid of the same size
Xmesh = np.c_[xx.ravel(), yy.ravel()] # np.c_([1, 2], [3, 4]) -> [[1, 3], [2, 4]]
inputs = [list(map(Value, xrow)) for xrow in Xmesh]
scores = list(map(model, inputs))
Z = np.array([s.data > 0 for s in scores])
Z = Z.reshape(xx.shape)

fig = plt.figure()
plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral, alpha=0.8)
plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.Spectral)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
# Out:
# (-1.548639298268643, 1.951360701731357)
